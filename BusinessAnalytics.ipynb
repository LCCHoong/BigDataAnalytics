# %%
import pandas as pd

martBranches = pd.read_csv("martBranches_cleaned.csv")
martCust = pd.read_csv("martCust_cleaned.csv")
martProd = pd.read_csv("martProd_cleaned.csv")
martProm = pd.read_csv("martProm_cleaned.csv")
martSales = pd.read_csv("martSales_cleaned.csv")
